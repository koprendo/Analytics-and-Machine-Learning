# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

pd.options.display.float_format = '{:,.3f}'.format
pd.set_option('display.max_columns', None)

# %% [markdown]
# veri üretme

# %%
cluster1 = np.random.normal(loc=[25, 4000, 30], scale=[3, 800, 10], size=(10, 3))
cluster2 = np.random.normal(loc=[40, 7000, 60], scale=[4, 1000, 12], size=(10, 3))
cluster3 = np.random.normal(loc=[55, 10000, 20], scale=[5, 1500, 8], size=(10, 3))

# %%
# Hepsini birleştirelim
data = np.vstack([cluster1, cluster2, cluster3])

# DataFrame’e atalım
df = pd.DataFrame(data, columns=["Age", "Income", "SpendingScore"])

df.head()
# Out:
#      Age    Income  SpendingScore
# 0 23.404 3,125.237         56.759
# 1 21.883 4,257.540         28.088
# 2 23.508 3,748.457         35.574
# 3 26.167 4,601.910         25.685
# 4 21.311 3,817.333         24.243

# %% [markdown]
# elbow method

# %% [markdown]
# k-means

# %% [markdown]
# 3-d görsel
